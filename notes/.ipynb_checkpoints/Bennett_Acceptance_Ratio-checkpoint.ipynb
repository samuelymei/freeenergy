# %% [markdown]
# In the calculations of thermodynamic properties, only only the accuracy but also the precision is our concern. Bennett Acceptance Ration (BAR), which was proposed by Bennett in 1976, is a method that yield the free energy difference between two states with minimal variance. Not like in thermodynamic perturbation, BAR requires simulations for both states. Starting from the definition of free energy difference
# \begin{align}
# \Delta A&=\ln{\frac{Q_0}{Q_1}}\notag\\
#       &=\ln{\frac{Q_0}{Q_1}\frac{\int W\exp{(-U_0-U_1)}d\mathbf{q}}{\int W\exp{(-U_0-U_1)}d\mathbf{q}}}\notag\\
#       &=\ln{\left\{\frac{\int W\exp{(-U_0)}\exp{(-U_1)}d\mathbf{q}}{Q_1}\cdot\frac{Q_0}{\int W\exp{(-U_1)}\exp{(-U_0)}d\mathbf{q}}\right\}}\notag\\
#       &=\ln{\frac{\left<W\exp{(-U_0)}\right>_1}{\left<W\exp{(-U_1)}\right>_0}},
# \end{align}
# where $W$ is an arbitrary normal weighting function. Optimization of the free energy estimate is most easily carried out in the limit of large sample sizes. Let the available data consist of $n_0$ statistically independent configurations from the $U_0$ ensemble and $n_1$ from the $U_1$ ensemble. Let the data be used in the above equation to obtain a finite-sample estimate of the reduced free energy difference $\Delta A$. Using the error propagation equation
# $$
# Var[y(x_1,x_2)]=\left(\frac{\partial y}{\partial x_1}\right)^2 Var(x_1) + \left(\frac{\partial y}{\partial x_2}\right)^2 Var(x_2),
# $$
# by assuming that $x_1$ and $x_2$ are independent, we have the variance of $\Delta A$
# \begin{align*}
# Var(\Delta A)&=\left(\frac{\partial \Delta A}{\partial Q_0}\right)^2 Var(Q_0)+\left(\frac{\partial \Delta A}{\partial Q_1}\right)^2 Var(Q_1)\\
#          &=\left(\frac{1}{Q_0}\right)^2 Var(Q_0)+\left(-\frac{1}{Q_1}\right)^2 Var(Q_1)\\
#          &=\left(\frac{1}{Q_0}\right)^2 Var(Q_0)+\left(\frac{1}{Q_1}\right)^2 Var(Q_1).
# \end{align*}
# With the definition of variance $Var(X)=\left<X^2\right>-\left<X\right>^2$, we have
# \begin{align*}
# Var(Q_0)&=Var\left(\left<W\exp{(-U_0)}\right>_1\right)\\
#      &=Var\left(\frac{1}{n_1}\sum_{i=1}^{n_1}W_i\exp{(-U_0(i))}\right)\\
#      &=\sum_{i=1}^{n_1}\left(\frac{1}{n_1}\right)^2Var\left\{W_i\exp{\left[-U_0(i)\right]}\right\}\\
#      &=\frac{1}{n_1}Var\left\{W_i\exp{\left[-U_0(i)\right]}\right\}\\
#      &=\frac{1}{n_1}\left\{\left<\left(W\exp{(-U_0)}\right)^2\right>_1-\left[\left<W\exp{(-U_0)}\right>_1\right]^2\right\}\\
#      &=\frac{1}{n_1}\left\{\left<W^2\exp{(-2U_0)}\right>_1-\left[\left<W\exp{(-U_0)}\right>_1\right]^2\right\}
# \end{align*}
# With sufficiently large sample sizes, the error of this estimate will be nearly Gaussian, and its expected square is exactly the variance of $\Delta A$
# \begin{align*}
# Var\left(\Delta A_{est}-\Delta A\right)&\approx\frac{\left<W^2\exp{(-2U_1)}\right>_0}{n_0\left[\left<W\exp{\left(-U_1\right)}\right>_0\right]^2}+\frac{\left<W^2\exp{(-2U_0)}\right>_1}{n_1\left[\left<W\exp{\left(-U_0\right)}\right>_1\right]^2}-\frac{1}{n_0}-\frac{1}{n_1}\\
# &=\frac{\int \left[(Q_0/n_0)\exp{(-U_1)+(Q_1/n_1)\exp{(-U_0)}}\right]W^2\exp{(-U_0-U_1)} d\mathbf{q}}{\left[\int W\exp{(-U_0-U_1)}d\mathbf{q}\right]^2}-\frac{1}{n_0}-\frac{1}{n_1}.
# \end{align*}
# To minimize it with respect to $W$, we find
# $$
# W=\mathit{const}\times\left(\frac{Q_0}{n_0}\exp{(-U_1)}+\frac{Q_1}{n_1}\exp{(-U_0)}\right)^{-1}.
# $$
#
# Substituting this into the definition of $\Delta A$ (please let me when equation numbering and references in Jupyter is available) yields
# $$
# \Delta A=\ln{\frac{Q_0}{Q_1}}=\ln{\frac{\left<f(U_0-U_1+C)\right>_1}{\left<f(U_1-U_0-C)\right>_0}}+C
# $$
# where
# $$
# C=\Delta A+\ln{\frac{n_1}{n_0}},
# $$
# and $f$ denotes the Fermi function
# $$
# f(x)=\frac{1}{1+\exp{(x)}}.
# $$
# Because $C$ and $\Delta A$ depend on each other, they must be solved iteratively.
#
# In this script, we are going to calculate the free energy difference between two states.
# State 0 has a Hamiltonian $H_0=(x+2.0)^2$ in one-dimensional space, and state 1 has a Hamiltonian $H_1=0.25(x-2.0)^2$. The free energy difference between these two states is
# \begin{align*}
# \Delta A&=\ln{\frac{\int \exp{(-H_0(\mathbf{x}))}d\mathbf{x}}{\int \exp{(-H_1(\mathbf{x}))}d\mathbf{x}}}\\
#      &=\ln{\frac{\int \exp{(-(x+2.0)^2)}d\mathbf{x}}{\int \exp{(-0.25\times(x-2.0)^2)}d\mathbf{x}}}\\
#      &=\ln{\frac{\sqrt{2\pi\times 0.5}}{\sqrt{2\pi\times 2}}}\\
#      &=-0.69
# \end{align*}

# %%
# %matplotlib inline
from math import *
import numpy as np
import random
import scipy.stats
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import random
np.set_printoptions(precision=3)
def u0(x):
    return (x+2.0)**2
def u1(x):
    return 0.25*(x-2.0)**2
x=np.linspace(-5,6,100)
y0=u0(x)
y1=u1(x)
plt.ylim(-.5, 3)
plt.plot(x,y0,'r',x,y1,'b')
plt.show()

# %% [markdown]
# Because the barrier is much larger than 1 in a unit of kT, it is difficult for TP to find the converged correct answer. Next we will use BAR to get the free energy difference.

# %% [markdown]
# Now we define a Monte Carlo (MC) propagator for this simulation.
# In the MC simulation, the transition between states must satisfy the detailed balance, i.e.
# $$\rho(x_i)P(x_i,x_j)=\rho(x_j)P(x_j,x_i),$$
# where $\rho(x_i)$ and $P(x_i,x_j)$ are the probability of the microstate $x_i$ and the transition probability from $x_i$ to $x_j$,
# respectively.
# Suppose at $t_0$ the system is located at microstate $x_0$ with energy u(x_0). We make a random trial move to $x_1^t$ with energy
# $u(x_1^t)$.
#
# if $u(x_1^t)<u(x_1^t)$
#
#   {
#   $x_1=x_1^t$
#   }
#
# else
#
#   {
#    generate a random number $s$ evenly distributed in [0,1]
#
#    if $s<e^{-[u(x_1^t)-u(x_1^t)]}$
#
#    {
#     $x_1=x_1^t$
#     }
#
#    else
#
#    {
#     $x_1=x_0$
#    }
#   }

# %%
def MCpropagator(x0,dx,N,dN,u):
    count = 0
    x = np.empty(N)
    xcurrent = x0
    while count <N:
        innercount = 0
        while innercount < dN:
            rnd = np.random.uniform(0.0,1.0)
            if rnd < 0.5:
                xtrial = xcurrent - dx
            else:
                xtrial = xcurrent + dx

            deltau = u(xtrial) - u(xcurrent)
            if deltau < 0.0:
                xcurrent = xtrial
            else:
                acceptanceratio = np.exp(-deltau)
                if acceptanceratio > np.random.uniform(0.0,1.0):
                    xcurrent = xtrial
                else:
                    xcurrent = xcurrent
            innercount = innercount + 1
        x[count]=xcurrent
        count = count + 1
    return x, count

# %%
dx = 0.01
dN = 1600
N0 = 5000
x_init0 = -2.0
x0 = np.empty(N0)
x0, count0 = MCpropagator(x_init0,dx,N0,dN,u0)
print('Number of samples generated for H0: %8d' %count0)
prob0, bins0, patches0 = plt.hist(x0, bins=50, density=True)
mean0 = np.mean(x0)
variance0 = np.var(x0)
sigma0 = np.sqrt(variance0)
npdf0 = scipy.stats.norm.pdf(bins0,mean0,sigma0)
plt.plot(bins0, npdf0, '--')

N1 = 10000
x_init1 = 2.0
x1 = np.empty(N0)
x1, count1 = MCpropagator(x_init1,dx,N1,dN,u1)
print('Number of samples generated for H1: %8d' %count1)

prob1, bins1, patches1 = plt.hist(x1, bins=50, density=True)
mean1 = np.mean(x1)
variance1 = np.var(x1)
sigma1 = np.sqrt(variance1)
npdf1 = scipy.stats.norm.pdf(bins1,mean1,sigma1)
plt.plot(bins1, npdf1, '--')

print('The distribution of the samples looks like:')
plt.xlim(-5,7)
plt.show()
# Out:
# Number of samples generated for H0:     5000
# Number of samples generated for H1:    10000
# The distribution of the samples looks like:

# %% [markdown]
# With these microstates sampled under $H_0$ and $H_1$, we calculate the free energy difference.

# %%
def fermi(x):
    return 1.0/(1+np.exp(x))

# %%
def BAR(u00,u11,u01,u10,count0,count1,deltaA=0.0,maxcycle=100,converg=1.E-4):
    icycle = 1
    while icycle <maxcycle:
        deltaA0=deltaA
        c=deltaA+log(float(count1)/count0)
        f0=fermi(u01-u00-c)
        f1=fermi(u10-u11+c)
        f0mean = np.mean(f0)
        f1mean = np.mean(f1)
        deltaA=log(f1mean/f0mean)+c
        #print('Cycle %d: Delta A=%5.2f' %(icycle, deltaA))
        if np.abs(deltaA0-deltaA)<converg:
            #print("Convergence has reached")
            return deltaA
        icycle += 1
    print("max cyclc reached. Return with nonconverged result")
    return deltaA

# %%
def bootstrap(u00,u11,u01,u10,count0,count1,nbs):
    bsu00=np.empty(count0)
    bsu01=np.empty(count0)
    bsu10=np.empty(count1)
    bsu11=np.empty(count1)
    deltaAs=np.empty(nbs)
    ibs = 0
    while ibs < nbs:
        print('Bootstrapping iteration %d/%d' % (ibs+1,nbs))
        irand = 0
        while irand < count0:
            idx = random.randint(0,count0-1)
            #print('%d, %d' % (irand,idx))
            bsu00[irand] = u00[idx]
            bsu01[irand] = u01[idx]
            irand += 1
        irand = 0
        while irand < count1:
            idx = random.randint(0,count1-1)
            #print('%d, %d' % (irand,idx))
            bsu10[irand] = u10[idx]
            bsu11[irand] = u11[idx]
            irand += 1
        deltaAs[ibs]=BAR(bsu00,bsu11,bsu01,bsu10,count0,count1,0.0,100)
        print('The free energy difference from a BAR calculation is %8.2f ' % (deltaAs[ibs]))
        ibs += 1
    deltaA=np.mean(deltaAs)
    vardeltaA=np.var(deltaAs)
    return deltaA,vardeltaA

# %%
def TP(u1,u0):
    N=u1.size
    edu = np.zeros(N)
    edu = np.exp(-(u1-u0))
    S = np.mean(edu)
    varS = np.var(edu)/N
    deltaA = -np.log(S)
    varA = varS/S**2
    return deltaA, varA

# %%
u00=u0(x0)
u11=u1(x1)
u01=u1(x0)
u10=u0(x1)

du01=u01-u00
probdu01, binsdu01, patchesdu01 = plt.hist(du01, bins=50, density=True)
meandu01 = np.mean(du01)
variancedu01 = np.var(du01)
sigmadu01 = np.sqrt(variancedu01)
npdfdu01 = scipy.stats.norm.pdf(binsdu01,meandu01,sigmadu01)
plt.plot(binsdu01, npdfdu01, '--')

du10=u10-u11
probdu10, binsdu10, patchesdu10 = plt.hist(du10, bins=50, density=True)
meandu10 = np.mean(du10)
variancedu10 = np.var(du10)
sigmadu10 = np.sqrt(variancedu10)
npdfdu10 = scipy.stats.norm.pdf(binsdu10,meandu10,sigmadu10)
plt.plot(binsdu10, npdfdu10, '--')

print('The distributions of delta U in forward and backward TP look like:')
plt.xlim(-20,60)
plt.show()

deltaA=0.0
deltaA,vardeltaA=bootstrap(u00,u11,u01,u10,count0,count1,1000)
print('\nThe free energy difference from a BAR calculation is %8.2f +- %5.2f\n' % (deltaA,sqrt(vardeltaA)))

fTPdA, fTPvardA = TP(u01,u00)
print('The free energy difference from a forward TP calculation is %8.2f +- %5.2f' % (fTPdA, sqrt(fTPvardA)))
feDis=np.mean(du01)-fTPdA
print('The dissipated work in a forward TP is %8.2f' % (feDis))

bTPdA, bTPvardA = TP(u10,u11)
bTPdA = -bTPdA
print('The free energy difference from a backward TP calculation is %8.2f +- %5.2f' % (bTPdA, sqrt(bTPvardA)))
beDis=np.mean(du10)+bTPdA
print('The dissipated work in a backward TP is %8.2f' % (beDis))


avgTPdA=fTPdA*((1/fTPvardA)/(1/fTPvardA+1/bTPvardA)) + bTPdA*((1/bTPvardA)/(1/fTPvardA+1/bTPvardA))
varavgTPdA=1/(1/fTPvardA+1/bTPvardA)
print('The free energy difference from the weighted average of the backward TP and forward TP is %8.2f +- %5.2f' % (avgTPdA, sqrt(varavgTPdA)))
# Out:
# The distributions of delta U in forward and backward TP look like:
# Bootstrapping iteration 1/1000
# The free energy difference from a BAR calculation is    -0.50
# Bootstrapping iteration 2/1000
# The free energy difference from a BAR calculation is    -0.45
# Bootstrapping iteration 3/1000
# The free energy difference from a BAR calculation is    -0.46
# Bootstrapping iteration 4/1000
# The free energy difference from a BAR calculation is    -0.44
# Bootstrapping iteration 5/1000
# The free energy difference from a BAR calculation is    -0.48
# Bootstrapping iteration 6/1000
# The free energy difference from a BAR calculation is    -0.49
# Bootstrapping iteration 7/1000
# The free energy difference from a BAR calculation is    -0.37
# Bootstrapping iteration 8/1000
# The free energy difference from a BAR calculation is    -0.44
# Bootstrapping iteration 9/1000
# The free energy difference from a BAR calculation is    -0.53
# Bootstrapping iteration 10/1000
# The free energy difference from a BAR calculation is    -0.46
# Bootstrapping iteration 11/1000
# The free energy difference from a BAR calculation is    -0.48
# Bootstrapping iteration 12/1000
# The free energy difference from a BAR calculation is    -0.41
# Bootstrapping iteration 13/1000
# The free energy difference from a BAR calculation is    -0.48
# Bootstrapping iteration 14/1000
# The free energy difference from a BAR calculation is    -0.43
# Bootstrapping iteration 15/1000
# The free energy difference from a BAR calculation is    -0.47
# Bootstrapping iteration 16/1000
# The free energy difference from a BAR calculation is    -0.41
# Bootstrapping iteration 17/1000
# The free energy difference from a BAR calculation is    -0.42
# Bootstrapping iteration 18/1000
# The free energy difference from a BAR calculation is    -0.50
# Bootstrapping iteration 19/1000
# The free energy difference from a BAR calculation is    -0.41
# Bootstrapping iteration 20/1000
# The free energy difference from a BAR calculation is    -0.51
# Bootstrapping iteration 21/1000
# The free energy difference from a BAR calculation is    -0.41
# Bootstrapping iteration 22/1000
# The free energy difference from a BAR calculation is    -0.45
# Bootstrapping iteration 23/1000
# The free energy difference from a BAR calculation is    -0.49
# Bootstrapping iteration 24/1000
# The free energy difference from a BAR calculation is    -0.38
# Bootstrapping iteration 25/1000
# The free energy difference from a BAR calculation is    -0.45
# Bootstrapping iteration 26/1000
# The free energy difference from a BAR calculation is    -0.58
# Bootstrapping iteration 27/1000
# The free energy difference from a BAR calculation is    -0.49
# Bootstrapping iteration 28/1000
# The free energy difference from a BAR calculation is    -0.53
# Bootstrapping iteration 29/1000
# The free energy difference from a BAR calculation is    -0.45
# Bootstrapping iteration 30/1000
# The free energy difference from a BAR calculation is    -0.46
# Bootstrapping iteration 31/1000
# The free energy difference from a BAR calculation is    -0.44
# Bootstrapping iteration 32/1000
# The free energy difference from a BAR calculation is    -0.40
# Bootstrapping iteration 33/1000
# The free energy difference from a BAR calculation is    -0.47
# Bootstrapping iteration 34/1000
# The free energy difference from a BAR calculation is    -0.39
# Bootstrapping iteration 35/1000
# The free energy difference from a BAR calculation is    -0.31
# Bootstrapping iteration 36/1000
# The free energy difference from a BAR calculation is    -0.42
# Bootstrapping iteration 37/1000
# The free energy difference from a BAR calculation is    -0.52
# Bootstrapping iteration 38/1000
# The free energy difference from a BAR calculation is    -0.45
# Bootstrapping iteration 39/1000
# The free energy difference from a BAR calculation is    -0.45
# Bootstrapping iteration 40/1000
# The free energy difference from a BAR calculation is    -0.52
# Bootstrapping iteration 41/1000
# The free energy difference from a BAR calculation is    -0.44
# Bootstrapping iteration 42/1000
# The free energy difference from a BAR calculation is    -0.45
# Bootstrapping iteration 43/1000
# The free energy difference from a BAR calculation is    -0.44
# Bootstrapping iteration 44/1000
# The free energy difference from a BAR calculation is    -0.46
# Bootstrapping iteration 45/1000
# The free energy difference from a BAR calculation is    -0.56
# Bootstrapping iteration 46/1000
# The free energy difference from a BAR calculation is    -0.48
# Bootstrapping iteration 47/1000
# The free energy difference from a BAR calculation is    -0.49
# Bootstrapping iteration 48/1000
# The free energy difference from a BAR calculation is    -0.43
# Bootstrapping iteration 49/1000
# The free energy difference from a BAR calculation is    -0.44
# Bootstrapping iteration 50/1000
# The free energy difference from a BAR calculation is    -0.31
# Bootstrapping iteration 51/1000
# The free energy difference from a BAR calculation is    -0.53
# Bootstrapping iteration 52/1000
# The free energy difference from a BAR calculation is    -0.46
# Bootstrapping iteration 53/1000
# The free energy difference from a BAR calculation is    -0.51
# Bootstrapping iteration 54/1000
# The free energy difference from a BAR calculation is    -0.41
# Bootstrapping iteration 55/1000
# The free energy difference from a BAR calculation is    -0.41
# Bootstrapping iteration 56/1000
# The free energy difference from a BAR calculation is    -0.46
# Bootstrapping iteration 57/1000
# The free energy difference from a BAR calculation is    -0.45
# Bootstrapping iteration 58/1000
# The free energy difference from a BAR calculation is    -0.46
# Bootstrapping iteration 59/1000
# The free energy difference from a BAR calculation is    -0.38
# Bootstrapping iteration 60/1000
# The free energy difference from a BAR calculation is    -0.34
# Bootstrapping iteration 61/1000
# The free energy difference from a BAR calculation is    -0.50
# Bootstrapping iteration 62/1000
# The free energy difference from a BAR calculation is    -0.47
# Bootstrapping iteration 63/1000
# The free energy difference from a BAR calculation is    -0.44
# Bootstrapping iteration 64/1000
# The free energy difference from a BAR calculation is    -0.52
# Bootstrapping iteration 65/1000
# The free energy difference from a BAR calculation is    -0.48
# Bootstrapping iteration 66/1000
# The free energy difference from a BAR calculation is    -0.42
# Bootstrapping iteration 67/1000
# The free energy difference from a BAR calculation is    -0.41
# Bootstrapping iteration 68/1000
# The free energy difference from a BAR calculation is    -0.47
# Bootstrapping iteration 69/1000
# The free energy difference from a BAR calculation is    -0.48
# Bootstrapping iteration 70/1000
# The free energy difference from a BAR calculation is    -0.45
# Bootstrapping iteration 71/1000
# The free energy difference from a BAR calculation is    -0.47
# Bootstrapping iteration 72/1000
# The free energy difference from a BAR calculation is    -0.49
# Bootstrapping iteration 73/1000
# The free energy difference from a BAR calculation is    -0.39
# Bootstrapping iteration 74/1000
# The free energy difference from a BAR calculation is    -0.49
# Bootstrapping iteration 75/1000
# The free energy difference from a BAR calculation is    -0.35
# Bootstrapping iteration 76/1000
# The free energy difference from a BAR calculation is    -0.44
# Bootstrapping iteration 77/1000
# The free energy difference from a BAR calculation is    -0.47
# Bootstrapping iteration 78/1000
# The free energy difference from a BAR calculation is    -0.47
# Bootstrapping iteration 79/1000
# The free energy difference from a BAR calculation is    -0.42
# Bootstrapping iteration 80/1000
# The free energy difference from a BAR calculation is    -0.46
# Bootstrapping iteration 81/1000
# The free energy difference from a BAR calculation is    -0.48
# Bootstrapping iteration 82/1000
# The free energy difference from a BAR calculation is    -0.45
# Bootstrapping iteration 83/1000
# The free energy difference from a BAR calculation is    -0.39
# Bootstrapping iteration 84/1000
# The free energy difference from a BAR calculation is    -0.43
# Bootstrapping iteration 85/1000
# The free energy difference from a BAR calculation is    -0.44
# Bootstrapping iteration 86/1000
# The free energy difference from a BAR calculation is    -0.44
# Bootstrapping iteration 87/1000
# The free energy difference from a BAR calculation is    -0.50
# Bootstrapping iteration 88/1000
# The free energy difference from a BAR calculation is    -0.48
# Bootstrapping iteration 89/1000
# The free energy difference from a BAR calculation is    -0.49
# Bootstrapping iteration 90/1000
# The free energy difference from a BAR calculation is    -0.50
# Bootstrapping iteration 91/1000
# The free energy difference from a BAR calculation is    -0.41
# Bootstrapping iteration 92/1000
# The free energy difference from a BAR calculation is    -0.49
# Bootstrapping iteration 93/1000
# The free energy difference from a BAR calculation is    -0.48
# Bootstrapping iteration 94/1000
# The free energy difference from a BAR calculation is    -0.53
# Bootstrapping iteration 95/1000
# The free energy difference from a BAR calculation is    -0.42
# Bootstrapping iteration 96/1000
# The free energy difference from a BAR calculation is    -0.47
# Bootstrapping iteration 97/1000
# The free energy difference from a BAR calculation is    -0.42
# Bootstrapping iteration 98/1000
# The free energy difference from a BAR calculation is    -0.46
# Bootstrapping iteration 99/1000
# The free energy difference from a BAR calculation is    -0.51
# Bootstrapping iteration 100/1000
# The free energy difference from a BAR calculation is    -0.53
# Bootstrapping iteration 101/1000
# The free energy difference from a BAR calculation is    -0.46
# Bootstrapping iteration 102/1000
# The free energy difference from a BAR calculation is    -0.51
# Bootstrapping iteration 103/1000
# The free energy difference from a BAR calculation is    -0.50
# Bootstrapping iteration 104/1000
# The free energy difference from a BAR calculation is    -0.48
# Bootstrapping iteration 105/1000
# The free energy difference from a BAR calculation is    -0.43
# Bootstrapping iteration 106/1000
# The free energy difference from a BAR calculation is    -0.43
# Bootstrapping iteration 107/1000
# The free energy difference from a BAR calculation is    -0.40
# Bootstrapping iteration 108/1000
# The free energy difference from a BAR calculation is    -0.46
# Bootstrapping iteration 109/1000
# The free energy difference from a BAR calculation is    -0.39
# Bootstrapping iteration 110/1000
# The free energy difference from a BAR calculation is    -0.48
# Bootstrapping iteration 111/1000
# The free energy difference from a BAR calculation is    -0.41
# Bootstrapping iteration 112/1000
# The free energy difference from a BAR calculation is    -0.56
# Bootstrapping iteration 113/1000
# The free energy difference from a BAR calculation is    -0.44
# Bootstrapping iteration 114/1000
# The free energy difference from a BAR calculation is    -0.52
# Bootstrapping iteration 115/1000
# The free energy difference from a BAR calculation is    -0.52
# Bootstrapping iteration 116/1000
# The free energy difference from a BAR calculation is    -0.47
# Bootstrapping iteration 117/1000
# The free energy difference from a BAR calculation is    -0.46
# Bootstrapping iteration 118/1000
# The free energy difference from a BAR calculation is    -0.55
# Bootstrapping iteration 119/1000
# The free energy difference from a BAR calculation is    -0.41
# Bootstrapping iteration 120/1000
# The free energy difference from a BAR calculation is    -0.43
# Bootstrapping iteration 121/1000
# The free energy difference from a BAR calculation is    -0.49
# Bootstrapping iteration 122/1000
# The free energy difference from a BAR calculation is    -0.38
# Bootstrapping iteration 123/1000
# The free energy difference from a BAR calculation is    -0.48
# Bootstrapping iteration 124/1000
# The free energy difference from a BAR calculation is    -0.48
# Bootstrapping iteration 125/1000
# The free energy difference from a BAR calculation is    -0.41
# Bootstrapping iteration 126/1000
# The free energy difference from a BAR calculation is    -0.46
# Bootstrapping iteration 127/1000
# The free energy difference from a BAR calculation is    -0.51
# Bootstrapping iteration 128/1000
# The free energy difference from a BAR calculation is    -0.35
# Bootstrapping iteration 129/1000
# The free energy difference from a BAR calculation is    -0.45
# Bootstrapping iteration 130/1000
# The free energy difference from a BAR calculation is    -0.54
# Bootstrapping iteration 131/1000
# The free energy difference from a BAR calculation is    -0.38
# Bootstrapping iteration 132/1000
# The free energy difference from a BAR calculation is    -0.42
# Bootstrapping iteration 133/1000
# The free energy difference from a BAR calculation is    -0.43
# Bootstrapping iteration 134/1000
# The free energy difference from a BAR calculation is    -0.41
# Bootstrapping iteration 135/1000
# The free energy difference from a BAR calculation is    -0.40
# Bootstrapping iteration 136/1000
# The free energy difference from a BAR calculation is    -0.44
# Bootstrapping iteration 137/1000
# The free energy difference from a BAR calculation is    -0.39
# Bootstrapping iteration 138/1000
# The free energy difference from a BAR calculation is    -0.48
# Bootstrapping iteration 139/1000
# The free energy difference from a BAR calculation is    -0.50
# Bootstrapping iteration 140/1000
# The free energy difference from a BAR calculation is    -0.49
# Bootstrapping iteration 141/1000
# The free energy difference from a BAR calculation is    -0.42
# Bootstrapping iteration 142/1000
# The free energy difference from a BAR calculation is    -0.46
# Bootstrapping iteration 143/1000
# The free energy difference from a BAR calculation is    -0.47
# Bootstrapping iteration 144/1000
# The free energy difference from a BAR calculation is    -0.47
# Bootstrapping iteration 145/1000
# The free energy difference from a BAR calculation is    -0.45
# Bootstrapping iteration 146/1000
# The free energy difference from a BAR calculation is    -0.43
# Bootstrapping iteration 147/1000
# The free energy difference from a BAR calculation is    -0.42
# Bootstrapping iteration 148/1000
# The free energy difference from a BAR calculation is    -0.43
# Bootstrapping iteration 149/1000
# The free energy difference from a BAR calculation is    -0.54
# Bootstrapping iteration 150/1000
# The free energy difference from a BAR calculation is    -0.47
# Bootstrapping iteration 151/1000
# The free energy difference from a BAR calculation is    -0.48
# Bootstrapping iteration 152/1000
# The free energy difference from a BAR calculation is    -0.51
# Bootstrapping iteration 153/1000
# The free energy difference from a BAR calculation is    -0.43
# Bootstrapping iteration 154/1000
# The free energy difference from a BAR calculation is    -0.35
# Bootstrapping iteration 155/1000
# The free energy difference from a BAR calculation is    -0.51
# Bootstrapping iteration 156/1000
# The free energy difference from a BAR calculation is    -0.50
# Bootstrapping iteration 157/1000
# The free energy difference from a BAR calculation is    -0.47
# Bootstrapping iteration 158/1000
# The free energy difference from a BAR calculation is    -0.51
# Bootstrapping iteration 159/1000
# The free energy difference from a BAR calculation is    -0.57
# Bootstrapping iteration 160/1000
# The free energy difference from a BAR calculation is    -0.51
# Bootstrapping iteration 161/1000
# The free energy difference from a BAR calculation is    -0.49
# Bootstrapping iteration 162/1000
# The free energy difference from a BAR calculation is    -0.36
# Bootstrapping iteration 163/1000
# The free energy difference from a BAR calculation is    -0.43
# Bootstrapping iteration 164/1000
# The free energy difference from a BAR calculation is    -0.49
# Bootstrapping iteration 165/1000
# The free energy difference from a BAR calculation is    -0.45
# Bootstrapping iteration 166/1000
# The free energy difference from a BAR calculation is    -0.54
# Bootstrapping iteration 167/1000
# The free energy difference from a BAR calculation is    -0.49
# Bootstrapping iteration 168/1000
# The free energy difference from a BAR calculation is    -0.56
# Bootstrapping iteration 169/1000
# The free energy difference from a BAR calculation is    -0.47
# Bootstrapping iteration 170/1000
# The free energy difference from a BAR calculation is    -0.44
# Bootstrapping iteration 171/1000
# The free energy difference from a BAR calculation is    -0.37
# Bootstrapping iteration 172/1000
# The free energy difference from a BAR calculation is    -0.51
# Bootstrapping iteration 173/1000
# The free energy difference from a BAR calculation is    -0.50
# Bootstrapping iteration 174/1000
# The free energy difference from a BAR calculation is    -0.54
# Bootstrapping iteration 175/1000
# The free energy difference from a BAR calculation is    -0.43
# Bootstrapping iteration 176/1000
# The free energy difference from a BAR calculation is    -0.46
# Bootstrapping iteration 177/1000
# The free energy difference from a BAR calculation is    -0.52
# Bootstrapping iteration 178/1000
# The free energy difference from a BAR calculation is    -0.46
# Bootstrapping iteration 179/1000
# The free energy difference from a BAR calculation is    -0.45
# Bootstrapping iteration 180/1000
# The free energy difference from a BAR calculation is    -0.52
# Bootstrapping iteration 181/1000
# The free energy difference from a BAR calculation is    -0.46
# Bootstrapping iteration 182/1000
# The free energy difference from a BAR calculation is    -0.38
# Bootstrapping iteration 183/1000
# The free energy difference from a BAR calculation is    -0.42
# Bootstrapping iteration 184/1000
# The free energy difference from a BAR calculation is    -0.55
# Bootstrapping iteration 185/1000
# The free energy difference from a BAR calculation is    -0.44
# Bootstrapping iteration 186/1000
# The free energy difference from a BAR calculation is    -0.51
# Bootstrapping iteration 187/1000
# The free energy difference from a BAR calculation is    -0.50
# Bootstrapping iteration 188/1000
# The free energy difference from a BAR calculation is    -0.51
# Bootstrapping iteration 189/1000
# The free energy difference from a BAR calculation is    -0.44
# Bootstrapping iteration 190/1000
# The free energy difference from a BAR calculation is    -0.49
# Bootstrapping iteration 191/1000
# The free energy difference from a BAR calculation is    -0.43
# Bootstrapping iteration 192/1000
# The free energy difference from a BAR calculation is    -0.46
# Bootstrapping iteration 193/1000
# The free energy difference from a BAR calculation is    -0.39
# Bootstrapping iteration 194/1000
# The free energy difference from a BAR calculation is    -0.50
# Bootstrapping iteration 195/1000
# The free energy difference from a BAR calculation is    -0.52
# Bootstrapping iteration 196/1000
# The free energy difference from a BAR calculation is    -0.46
# Bootstrapping iteration 197/1000
# The free energy difference from a BAR calculation is    -0.49
# Bootstrapping iteration 198/1000
# The free energy difference from a BAR calculation is    -0.53
# Bootstrapping iteration 199/1000
# The free energy difference from a BAR calculation is    -0.50
# Bootstrapping iteration 200/1000
# The free energy difference from a BAR calculation is    -0.43
# Bootstrapping iteration 201/1000
# The free energy difference from a BAR calculation is    -0.50
# Bootstrapping iteration 202/1000
# The free energy difference from a BAR calculation is    -0.38
# Bootstrapping iteration 203/1000
# The free energy difference from a BAR calculation is    -0.37
# Bootstrapping iteration 204/1000
# The free energy difference from a BAR calculation is    -0.56
# Bootstrapping iteration 205/1000
# The free energy difference from a BAR calculation is    -0.46
# Bootstrapping iteration 206/1000
# The free energy difference from a BAR calculation is    -0.41
# Bootstrapping iteration 207/1000
# The free energy difference from a BAR calculation is    -0.47
# Bootstrapping iteration 208/1000
# The free energy difference from a BAR calculation is    -0.37
# Bootstrapping iteration 209/1000
# The free energy difference from a BAR calculation is    -0.53
# Bootstrapping iteration 210/1000
# The free energy difference from a BAR calculation is    -0.43
# Bootstrapping iteration 211/1000
# The free energy difference from a BAR calculation is    -0.47
# Bootstrapping iteration 212/1000
# The free energy difference from a BAR calculation is    -0.47
# Bootstrapping iteration 213/1000
# The free energy difference from a BAR calculation is    -0.52
# Bootstrapping iteration 214/1000
# The free energy difference from a BAR calculation is    -0.52
# Bootstrapping iteration 215/1000
# The free energy difference from a BAR calculation is    -0.50
# Bootstrapping iteration 216/1000
# The free energy difference from a BAR calculation is    -0.51
# Bootstrapping iteration 217/1000
# The free energy difference from a BAR calculation is    -0.38
# Bootstrapping iteration 218/1000
# The free energy difference from a BAR calculation is    -0.56
# Bootstrapping iteration 219/1000
# The free energy difference from a BAR calculation is    -0.50
# Bootstrapping iteration 220/1000
# The free energy difference from a BAR calculation is    -0.43
# Bootstrapping iteration 221/1000
# The free energy difference from a BAR calculation is    -0.47
# Bootstrapping iteration 222/1000
# The free energy difference from a BAR calculation is    -0.53
# Bootstrapping iteration 223/1000
# The free energy difference from a BAR calculation is    -0.42
# Bootstrapping iteration 224/1000
# The free energy difference from a BAR calculation is    -0.38
# Bootstrapping iteration 225/1000
# The free energy difference from a BAR calculation is    -0.46
# Bootstrapping iteration 226/1000
# The free energy difference from a BAR calculation is    -0.45
# Bootstrapping iteration 227/1000
# The free energy difference from a BAR calculation is    -0.47
# Bootstrapping iteration 228/1000
# The free energy difference from a BAR calculation is    -0.52
# Bootstrapping iteration 229/1000
# The free energy difference from a BAR calculation is    -0.49
# Bootstrapping iteration 230/1000
# The free energy difference from a BAR calculation is    -0.51
# Bootstrapping iteration 231/1000
# The free energy difference from a BAR calculation is    -0.44
# Bootstrapping iteration 232/1000
# The free energy difference from a BAR calculation is    -0.40
# Bootstrapping iteration 233/1000
# The free energy difference from a BAR calculation is    -0.42
# Bootstrapping iteration 234/1000
# The free energy difference from a BAR calculation is    -0.48
# Bootstrapping iteration 235/1000
# The free energy difference from a BAR calculation is    -0.41
# Bootstrapping iteration 236/1000
# The free energy difference from a BAR calculation is    -0.41
# Bootstrapping iteration 237/1000
# The free energy difference from a BAR calculation is    -0.50
# Bootstrapping iteration 238/1000
# The free energy difference from a BAR calculation is    -0.56
# Bootstrapping iteration 239/1000
# The free energy difference from a BAR calculation is    -0.48
# Bootstrapping iteration 240/1000
# The free energy difference from a BAR calculation is    -0.45
# Bootstrapping iteration 241/1000
# The free energy difference from a BAR calculation is    -0.46
# Bootstrapping iteration 242/1000
# The free energy difference from a BAR calculation is    -0.50
# Bootstrapping iteration 243/1000
# The free energy difference from a BAR calculation is    -0.43
# Bootstrapping iteration 244/1000
# The free energy difference from a BAR calculation is    -0.47
# Bootstrapping iteration 245/1000
# The free energy difference from a BAR calculation is    -0.44
# Bootstrapping iteration 246/1000
# The free energy difference from a BAR calculation is    -0.48
# Bootstrapping iteration 247/1000
# The free energy difference from a BAR calculation is    -0.47
# Bootstrapping iteration 248/1000
# The free energy difference from a BAR calculation is    -0.38
# Bootstrapping iteration 249/1000
# The free energy difference from a BAR calculation is    -0.40
# Bootstrapping iteration 250/1000
# The free energy difference from a BAR calculation is    -0.43
# Bootstrapping iteration 251/1000
# The free energy difference from a BAR calculation is    -0.50
# Bootstrapping iteration 252/1000
# The free energy difference from a BAR calculation is    -0.39
# Bootstrapping iteration 253/1000
# The free energy difference from a BAR calculation is    -0.52
# Bootstrapping iteration 254/1000
# The free energy difference from a BAR calculation is    -0.41
# Bootstrapping iteration 255/1000
# The free energy difference from a BAR calculation is    -0.41
# Bootstrapping iteration 256/1000
# The free energy difference from a BAR calculation is    -0.51
# Bootstrapping iteration 257/1000
# The free energy difference from a BAR calculation is    -0.41
# Bootstrapping iteration 258/1000
# The free energy difference from a BAR calculation is    -0.39
# Bootstrapping iteration 259/1000
# The free energy difference from a BAR calculation is    -0.41
# Bootstrapping iteration 260/1000
# The free energy difference from a BAR calculation is    -0.51
# Bootstrapping iteration 261/1000
# The free energy difference from a BAR calculation is    -0.48
# Bootstrapping iteration 262/1000
# The free energy difference from a BAR calculation is    -0.42
# Bootstrapping iteration 263/1000
# The free energy difference from a BAR calculation is    -0.42
# Bootstrapping iteration 264/1000
# The free energy difference from a BAR calculation is    -0.47
# Bootstrapping iteration 265/1000
# The free energy difference from a BAR calculation is    -0.44
# Bootstrapping iteration 266/1000
# The free energy difference from a BAR calculation is    -0.46
# Bootstrapping iteration 267/1000
# The free energy difference from a BAR calculation is    -0.45
# Bootstrapping iteration 268/1000
# The free energy difference from a BAR calculation is    -0.41
# Bootstrapping iteration 269/1000
# The free energy difference from a BAR calculation is    -0.44
# Bootstrapping iteration 270/1000
# The free energy difference from a BAR calculation is    -0.51
# Bootstrapping iteration 271/1000
# The free energy difference from a BAR calculation is    -0.49
# Bootstrapping iteration 272/1000
# The free energy difference from a BAR calculation is    -0.44
# Bootstrapping iteration 273/1000
# The free energy difference from a BAR calculation is    -0.44
# Bootstrapping iteration 274/1000
# The free energy difference from a BAR calculation is    -0.51
# Bootstrapping iteration 275/1000
# The free energy difference from a BAR calculation is    -0.45
# Bootstrapping iteration 276/1000
# The free energy difference from a BAR calculation is    -0.43
# Bootstrapping iteration 277/1000
# The free energy difference from a BAR calculation is    -0.40
# Bootstrapping iteration 278/1000
# The free energy difference from a BAR calculation is    -0.41
# Bootstrapping iteration 279/1000
# The free energy difference from a BAR calculation is    -0.43
# Bootstrapping iteration 280/1000
# The free energy difference from a BAR calculation is    -0.39
# Bootstrapping iteration 281/1000
# The free energy difference from a BAR calculation is    -0.47
# Bootstrapping iteration 282/1000
# The free energy difference from a BAR calculation is    -0.36
# Bootstrapping iteration 283/1000
# The free energy difference from a BAR calculation is    -0.48
# Bootstrapping iteration 284/1000
# The free energy difference from a BAR calculation is    -0.44
# Bootstrapping iteration 285/1000
# The free energy difference from a BAR calculation is    -0.52
# Bootstrapping iteration 286/1000
# The free energy difference from a BAR calculation is    -0.42
# Bootstrapping iteration 287/1000
# The free energy difference from a BAR calculation is    -0.54
# Bootstrapping iteration 288/1000
# The free energy difference from a BAR calculation is    -0.41
# Bootstrapping iteration 289/1000
# The free energy difference from a BAR calculation is    -0.36
# Bootstrapping iteration 290/1000
# The free energy difference from a BAR calculation is    -0.49
# Bootstrapping iteration 291/1000
# The free energy difference from a BAR calculation is    -0.43
# Bootstrapping iteration 292/1000
# The free energy difference from a BAR calculation is    -0.50
# Bootstrapping iteration 293/1000
# The free energy difference from a BAR calculation is    -0.47
# Bootstrapping iteration 294/1000
# The free energy difference from a BAR calculation is    -0.41
# Bootstrapping iteration 295/1000
# The free energy difference from a BAR calculation is    -0.56
# Bootstrapping iteration 296/1000
# The free energy difference from a BAR calculation is    -0.53
# Bootstrapping iteration 297/1000
# The free energy difference from a BAR calculation is    -0.47
# Bootstrapping iteration 298/1000
# The free energy difference from a BAR calculation is    -0.46
# Bootstrapping iteration 299/1000
# The free energy difference from a BAR calculation is    -0.43
# Bootstrapping iteration 300/1000
# The free energy difference from a BAR calculation is    -0.42
# Bootstrapping iteration 301/1000
# The free energy difference from a BAR calculation is    -0.44
# Bootstrapping iteration 302/1000
# The free energy difference from a BAR calculation is    -0.44
# Bootstrapping iteration 303/1000
# The free energy difference from a BAR calculation is    -0.45
# Bootstrapping iteration 304/1000
# The free energy difference from a BAR calculation is    -0.49
# Bootstrapping iteration 305/1000
# The free energy difference from a BAR calculation is    -0.49
# Bootstrapping iteration 306/1000
# The free energy difference from a BAR calculation is    -0.48
# Bootstrapping iteration 307/1000
# The free energy difference from a BAR calculation is    -0.51
# Bootstrapping iteration 308/1000
# The free energy difference from a BAR calculation is    -0.50
# Bootstrapping iteration 309/1000
# The free energy difference from a BAR calculation is    -0.42
# Bootstrapping iteration 310/1000
# The free energy difference from a BAR calculation is    -0.42
# Bootstrapping iteration 311/1000
# The free energy difference from a BAR calculation is    -0.48
# Bootstrapping iteration 312/1000
# The free energy difference from a BAR calculation is    -0.48
# Bootstrapping iteration 313/1000
# The free energy difference from a BAR calculation is    -0.45
# Bootstrapping iteration 314/1000
# The free energy difference from a BAR calculation is    -0.49
# Bootstrapping iteration 315/1000
# The free energy difference from a BAR calculation is    -0.40
# Bootstrapping iteration 316/1000
# The free energy difference from a BAR calculation is    -0.43
# Bootstrapping iteration 317/1000
# The free energy difference from a BAR calculation is    -0.50
# Bootstrapping iteration 318/1000
# The free energy difference from a BAR calculation is    -0.42
# Bootstrapping iteration 319/1000
# The free energy difference from a BAR calculation is    -0.42
# Bootstrapping iteration 320/1000
# The free energy difference from a BAR calculation is    -0.43
# Bootstrapping iteration 321/1000
# The free energy difference from a BAR calculation is    -0.46
# Bootstrapping iteration 322/1000
# The free energy difference from a BAR calculation is    -0.48
# Bootstrapping iteration 323/1000
# The free energy difference from a BAR calculation is    -0.37
# Bootstrapping iteration 324/1000
# The free energy difference from a BAR calculation is    -0.42
# Bootstrapping iteration 325/1000
# The free energy difference from a BAR calculation is    -0.52
# Bootstrapping iteration 326/1000
# The free energy difference from a BAR calculation is    -0.56
# Bootstrapping iteration 327/1000
# The free energy difference from a BAR calculation is    -0.54
# Bootstrapping iteration 328/1000
# The free energy difference from a BAR calculation is    -0.48
# Bootstrapping iteration 329/1000
# The free energy difference from a BAR calculation is    -0.52
# Bootstrapping iteration 330/1000
# The free energy difference from a BAR calculation is    -0.48
# Bootstrapping iteration 331/1000
# The free energy difference from a BAR calculation is    -0.48
# Bootstrapping iteration 332/1000
# The free energy difference from a BAR calculation is    -0.54
# Bootstrapping iteration 333/1000
# The free energy difference from a BAR calculation is    -0.51
# Bootstrapping iteration 334/1000
# The free energy difference from a BAR calculation is    -0.53
# Bootstrapping iteration 335/1000
# The free energy difference from a BAR calculation is    -0.47
# Bootstrapping iteration 336/1000
# The free energy difference from a BAR calculation is    -0.36
# Bootstrapping iteration 337/1000
# The free energy difference from a BAR calculation is    -0.49
# Bootstrapping iteration 338/1000
# The free energy difference from a BAR calculation is    -0.51
# Bootstrapping iteration 339/1000
# The free energy difference from a BAR calculation is    -0.48
# Bootstrapping iteration 340/1000
# The free energy difference from a BAR calculation is    -0.52
# Bootstrapping iteration 341/1000
# The free energy difference from a BAR calculation is    -0.45
# Bootstrapping iteration 342/1000
# The free energy difference from a BAR calculation is    -0.39
# Bootstrapping iteration 343/1000
# The free energy difference from a BAR calculation is    -0.46
# Bootstrapping iteration 344/1000
# The free energy difference from a BAR calculation is    -0.34
# Bootstrapping iteration 345/1000
# The free energy difference from a BAR calculation is    -0.50
# Bootstrapping iteration 346/1000
# The free energy difference from a BAR calculation is    -0.47
# Bootstrapping iteration 347/1000
# The free energy difference from a BAR calculation is    -0.42
# Bootstrapping iteration 348/1000
# The free energy difference from a BAR calculation is    -0.54
# Bootstrapping iteration 349/1000
# The free energy difference from a BAR calculation is    -0.40
# Bootstrapping iteration 350/1000
# The free energy difference from a BAR calculation is    -0.46
# Bootstrapping iteration 351/1000
# The free energy difference from a BAR calculation is    -0.39
# Bootstrapping iteration 352/1000
# The free energy difference from a BAR calculation is    -0.41
# Bootstrapping iteration 353/1000
# The free energy difference from a BAR calculation is    -0.59
# Bootstrapping iteration 354/1000
# The free energy difference from a BAR calculation is    -0.45
# Bootstrapping iteration 355/1000
# The free energy difference from a BAR calculation is    -0.48
# Bootstrapping iteration 356/1000
# The free energy difference from a BAR calculation is    -0.49
# Bootstrapping iteration 357/1000
# The free energy difference from a BAR calculation is    -0.47
# Bootstrapping iteration 358/1000
# The free energy difference from a BAR calculation is    -0.45
# Bootstrapping iteration 359/1000
# The free energy difference from a BAR calculation is    -0.46
# Bootstrapping iteration 360/1000
# The free energy difference from a BAR calculation is    -0.44
# Bootstrapping iteration 361/1000
# The free energy difference from a BAR calculation is    -0.47
# Bootstrapping iteration 362/1000
# The free energy difference from a BAR calculation is    -0.43
# Bootstrapping iteration 363/1000
# The free energy difference from a BAR calculation is    -0.38
# Bootstrapping iteration 364/1000
# The free energy difference from a BAR calculation is    -0.43
# Bootstrapping iteration 365/1000
# The free energy difference from a BAR calculation is    -0.47
# Bootstrapping iteration 366/1000
# The free energy difference from a BAR calculation is    -0.48
# Bootstrapping iteration 367/1000
# The free energy difference from a BAR calculation is    -0.46
# Bootstrapping iteration 368/1000
# The free energy difference from a BAR calculation is    -0.41
# Bootstrapping iteration 369/1000
# The free energy difference from a BAR calculation is    -0.50
# Bootstrapping iteration 370/1000
# The free energy difference from a BAR calculation is    -0.42
# Bootstrapping iteration 371/1000
# The free energy difference from a BAR calculation is    -0.49
# Bootstrapping iteration 372/1000
# The free energy difference from a BAR calculation is    -0.42
# Bootstrapping iteration 373/1000
# The free energy difference from a BAR calculation is    -0.49
# Bootstrapping iteration 374/1000
# The free energy difference from a BAR calculation is    -0.49
# Bootstrapping iteration 375/1000
# The free energy difference from a BAR calculation is    -0.51
# Bootstrapping iteration 376/1000
# The free energy difference from a BAR calculation is    -0.46
# Bootstrapping iteration 377/1000
# The free energy difference from a BAR calculation is    -0.47
# Bootstrapping iteration 378/1000
# The free energy difference from a BAR calculation is    -0.45
# Bootstrapping iteration 379/1000
# The free energy difference from a BAR calculation is    -0.47
# Bootstrapping iteration 380/1000
# The free energy difference from a BAR calculation is    -0.49
# Bootstrapping iteration 381/1000
# The free energy difference from a BAR calculation is    -0.48
# Bootstrapping iteration 382/1000
# The free energy difference from a BAR calculation is    -0.49
# Bootstrapping iteration 383/1000
# The free energy difference from a BAR calculation is    -0.44
# Bootstrapping iteration 384/1000
# The free energy difference from a BAR calculation is    -0.48
# Bootstrapping iteration 385/1000
# The free energy difference from a BAR calculation is    -0.49
# Bootstrapping iteration 386/1000
# The free energy difference from a BAR calculation is    -0.44
# Bootstrapping iteration 387/1000
# The free energy difference from a BAR calculation is    -0.49
# Bootstrapping iteration 388/1000
# The free energy difference from a BAR calculation is    -0.41
# Bootstrapping iteration 389/1000
# The free energy difference from a BAR calculation is    -0.45
# Bootstrapping iteration 390/1000
# The free energy difference from a BAR calculation is    -0.52
# Bootstrapping iteration 391/1000
# The free energy difference from a BAR calculation is    -0.41
# Bootstrapping iteration 392/1000
# The free energy difference from a BAR calculation is    -0.45
# Bootstrapping iteration 393/1000
# The free energy difference from a BAR calculation is    -0.44
# Bootstrapping iteration 394/1000
# The free energy difference from a BAR calculation is    -0.51
# Bootstrapping iteration 395/1000
# The free energy difference from a BAR calculation is    -0.43
# Bootstrapping iteration 396/1000
# The free energy difference from a BAR calculation is    -0.53
# Bootstrapping iteration 397/1000
# The free energy difference from a BAR calculation is    -0.51
# Bootstrapping iteration 398/1000
# The free energy difference from a BAR calculation is    -0.46
# Bootstrapping iteration 399/1000
# The free energy difference from a BAR calculation is    -0.50
# Bootstrapping iteration 400/1000
# The free energy difference from a BAR calculation is    -0.36
# Bootstrapping iteration 401/1000
# The free energy difference from a BAR calculation is    -0.51
# Bootstrapping iteration 402/1000
# The free energy difference from a BAR calculation is    -0.42
# Bootstrapping iteration 403/1000
# The free energy difference from a BAR calculation is    -0.39
# Bootstrapping iteration 404/1000
# The free energy difference from a BAR calculation is    -0.52
# Bootstrapping iteration 405/1000
# The free energy difference from a BAR calculation is    -0.54
# Bootstrapping iteration 406/1000
# The free energy difference from a BAR calculation is    -0.54
# Bootstrapping iteration 407/1000
# The free energy difference from a BAR calculation is    -0.43
# Bootstrapping iteration 408/1000
# The free energy difference from a BAR calculation is    -0.48
# Bootstrapping iteration 409/1000
# The free energy difference from a BAR calculation is    -0.43
# Bootstrapping iteration 410/1000
# The free energy difference from a BAR calculation is    -0.50
# Bootstrapping iteration 411/1000
# The free energy difference from a BAR calculation is    -0.45
# Bootstrapping iteration 412/1000
# The free energy difference from a BAR calculation is    -0.48
# Bootstrapping iteration 413/1000
# The free energy difference from a BAR calculation is    -0.55
# Bootstrapping iteration 414/1000
# The free energy difference from a BAR calculation is    -0.53
# Bootstrapping iteration 415/1000
# The free energy difference from a BAR calculation is    -0.53
# Bootstrapping iteration 416/1000
# The free energy difference from a BAR calculation is    -0.46
# Bootstrapping iteration 417/1000
# The free energy difference from a BAR calculation is    -0.42
# Bootstrapping iteration 418/1000
# The free energy difference from a BAR calculation is    -0.37
# Bootstrapping iteration 419/1000
# The free energy difference from a BAR calculation is    -0.53
# Bootstrapping iteration 420/1000
# The free energy difference from a BAR calculation is    -0.45
# Bootstrapping iteration 421/1000
# The free energy difference from a BAR calculation is    -0.45
# Bootstrapping iteration 422/1000
# The free energy difference from a BAR calculation is    -0.40
# Bootstrapping iteration 423/1000
# The free energy difference from a BAR calculation is    -0.50
# Bootstrapping iteration 424/1000
# The free energy difference from a BAR calculation is    -0.50
# Bootstrapping iteration 425/1000
# The free energy difference from a BAR calculation is    -0.43
# Bootstrapping iteration 426/1000
# The free energy difference from a BAR calculation is    -0.47
# Bootstrapping iteration 427/1000
# The free energy difference from a BAR calculation is    -0.51
# Bootstrapping iteration 428/1000
# The free energy difference from a BAR calculation is    -0.51
# Bootstrapping iteration 429/1000
# The free energy difference from a BAR calculation is    -0.41
# Bootstrapping iteration 430/1000
# The free energy difference from a BAR calculation is    -0.45
# Bootstrapping iteration 431/1000
# The free energy difference from a BAR calculation is    -0.41
# Bootstrapping iteration 432/1000
# The free energy difference from a BAR calculation is    -0.40
# Bootstrapping iteration 433/1000
# The free energy difference from a BAR calculation is    -0.50
# Bootstrapping iteration 434/1000
# The free energy difference from a BAR calculation is    -0.52
# Bootstrapping iteration 435/1000
# The free energy difference from a BAR calculation is    -0.46
# Bootstrapping iteration 436/1000
# The free energy difference from a BAR calculation is    -0.56
# Bootstrapping iteration 437/1000
# The free energy difference from a BAR calculation is    -0.49
# Bootstrapping iteration 438/1000
# The free energy difference from a BAR calculation is    -0.43
# Bootstrapping iteration 439/1000
# The free energy difference from a BAR calculation is    -0.39
# Bootstrapping iteration 440/1000
# The free energy difference from a BAR calculation is    -0.48
# Bootstrapping iteration 441/1000
# The free energy difference from a BAR calculation is    -0.41
# Bootstrapping iteration 442/1000
# The free energy difference from a BAR calculation is    -0.49
# Bootstrapping iteration 443/1000
# The free energy difference from a BAR calculation is    -0.43
# Bootstrapping iteration 444/1000
# The free energy difference from a BAR calculation is    -0.43
# Bootstrapping iteration 445/1000
# The free energy difference from a BAR calculation is    -0.50
# Bootstrapping iteration 446/1000
# The free energy difference from a BAR calculation is    -0.37
# Bootstrapping iteration 447/1000
# The free energy difference from a BAR calculation is    -0.46
# Bootstrapping iteration 448/1000
# The free energy difference from a BAR calculation is    -0.51
# Bootstrapping iteration 449/1000
# The free energy difference from a BAR calculation is    -0.45
# Bootstrapping iteration 450/1000
# The free energy difference from a BAR calculation is    -0.42
# Bootstrapping iteration 451/1000
# The free energy difference from a BAR calculation is    -0.50
# Bootstrapping iteration 452/1000
# The free energy difference from a BAR calculation is    -0.45
# Bootstrapping iteration 453/1000
# The free energy difference from a BAR calculation is    -0.43
# Bootstrapping iteration 454/1000
# The free energy difference from a BAR calculation is    -0.51
# Bootstrapping iteration 455/1000
# The free energy difference from a BAR calculation is    -0.46
# Bootstrapping iteration 456/1000
# The free energy difference from a BAR calculation is    -0.50
# Bootstrapping iteration 457/1000
# The free energy difference from a BAR calculation is    -0.48
# Bootstrapping iteration 458/1000
# The free energy difference from a BAR calculation is    -0.45
# Bootstrapping iteration 459/1000
# The free energy difference from a BAR calculation is    -0.44
# Bootstrapping iteration 460/1000
# The free energy difference from a BAR calculation is    -0.49
# Bootstrapping iteration 461/1000
# The free energy difference from a BAR calculation is    -0.50
# Bootstrapping iteration 462/1000
# The free energy difference from a BAR calculation is    -0.46
# Bootstrapping iteration 463/1000
# The free energy difference from a BAR calculation is    -0.50
# Bootstrapping iteration 464/1000
# The free energy difference from a BAR calculation is    -0.42
# Bootstrapping iteration 465/1000
# The free energy difference from a BAR calculation is    -0.49
# Bootstrapping iteration 466/1000
# The free energy difference from a BAR calculation is    -0.42
# Bootstrapping iteration 467/1000
# The free energy difference from a BAR calculation is    -0.54
# Bootstrapping iteration 468/1000
# The free energy difference from a BAR calculation is    -0.53
# Bootstrapping iteration 469/1000
# The free energy difference from a BAR calculation is    -0.47
# Bootstrapping iteration 470/1000
# The free energy difference from a BAR calculation is    -0.45
# Bootstrapping iteration 471/1000
# The free energy difference from a BAR calculation is    -0.42
# Bootstrapping iteration 472/1000
# The free energy difference from a BAR calculation is    -0.43
# Bootstrapping iteration 473/1000
# The free energy difference from a BAR calculation is    -0.50
# Bootstrapping iteration 474/1000
# The free energy difference from a BAR calculation is    -0.44
# Bootstrapping iteration 475/1000
# The free energy difference from a BAR calculation is    -0.51
# Bootstrapping iteration 476/1000
# The free energy difference from a BAR calculation is    -0.40
# Bootstrapping iteration 477/1000
# The free energy difference from a BAR calculation is    -0.50
# Bootstrapping iteration 478/1000
# The free energy difference from a BAR calculation is    -0.45
# Bootstrapping iteration 479/1000
# The free energy difference from a BAR calculation is    -0.43
# Bootstrapping iteration 480/1000
# The free energy difference from a BAR calculation is    -0.50
# Bootstrapping iteration 481/1000
# The free energy difference from a BAR calculation is    -0.47
# Bootstrapping iteration 482/1000
# The free energy difference from a BAR calculation is    -0.48
# Bootstrapping iteration 483/1000
# The free energy difference from a BAR calculation is    -0.48
# Bootstrapping iteration 484/1000
# The free energy difference from a BAR calculation is    -0.52
# Bootstrapping iteration 485/1000
# The free energy difference from a BAR calculation is    -0.55
# Bootstrapping iteration 486/1000
# The free energy difference from a BAR calculation is    -0.40
# Bootstrapping iteration 487/1000
# The free energy difference from a BAR calculation is    -0.47
# Bootstrapping iteration 488/1000
# The free energy difference from a BAR calculation is    -0.46
# Bootstrapping iteration 489/1000
# The free energy difference from a BAR calculation is    -0.45
# Bootstrapping iteration 490/1000
# The free energy difference from a BAR calculation is    -0.50
# Bootstrapping iteration 491/1000
# The free energy difference from a BAR calculation is    -0.38
# Bootstrapping iteration 492/1000
# The free energy difference from a BAR calculation is    -0.45
# Bootstrapping iteration 493/1000
# The free energy difference from a BAR calculation is    -0.45
# Bootstrapping iteration 494/1000
# The free energy difference from a BAR calculation is    -0.46
# Bootstrapping iteration 495/1000
# The free energy difference from a BAR calculation is    -0.53
# Bootstrapping iteration 496/1000
# The free energy difference from a BAR calculation is    -0.44
# Bootstrapping iteration 497/1000
# The free energy difference from a BAR calculation is    -0.48
# Bootstrapping iteration 498/1000
# The free energy difference from a BAR calculation is    -0.50
# Bootstrapping iteration 499/1000
# The free energy difference from a BAR calculation is    -0.48
# Bootstrapping iteration 500/1000
# The free energy difference from a BAR calculation is    -0.55
# Bootstrapping iteration 501/1000
# ...
# Bootstrapping iteration 839/1000
# The free energy difference from a BAR calculation is    -0.44
# Bootstrapping iteration 840/1000
# The free energy difference from a BAR calculation is    -0.43
# Bootstrapping iteration 841/1000
# The free energy difference from a BAR calculation is    -0.49
# Bootstrapping iteration 842/1000
# The free energy difference from a BAR calculation is    -0.52
# Bootstrapping iteration 843/1000
# The free energy difference from a BAR calculation is    -0.40
# Bootstrapping iteration 844/1000
# The free energy difference from a BAR calculation is    -0.49
# Bootstrapping iteration 845/1000
# The free energy difference from a BAR calculation is    -0.47
# Bootstrapping iteration 846/1000
# The free energy difference from a BAR calculation is    -0.49
# Bootstrapping iteration 847/1000
# The free energy difference from a BAR calculation is    -0.52
# Bootstrapping iteration 848/1000
# The free energy difference from a BAR calculation is    -0.40
# Bootstrapping iteration 849/1000
# The free energy difference from a BAR calculation is    -0.47
# Bootstrapping iteration 850/1000
# The free energy difference from a BAR calculation is    -0.51
# Bootstrapping iteration 851/1000
# The free energy difference from a BAR calculation is    -0.48
# Bootstrapping iteration 852/1000
# The free energy difference from a BAR calculation is    -0.50
# Bootstrapping iteration 853/1000
# The free energy difference from a BAR calculation is    -0.46
# Bootstrapping iteration 854/1000
# The free energy difference from a BAR calculation is    -0.40
# Bootstrapping iteration 855/1000
# The free energy difference from a BAR calculation is    -0.46
# Bootstrapping iteration 856/1000
# The free energy difference from a BAR calculation is    -0.51
# Bootstrapping iteration 857/1000
# The free energy difference from a BAR calculation is    -0.53
# Bootstrapping iteration 858/1000
# The free energy difference from a BAR calculation is    -0.49
# Bootstrapping iteration 859/1000
# The free energy difference from a BAR calculation is    -0.50
# Bootstrapping iteration 860/1000
# The free energy difference from a BAR calculation is    -0.46
# Bootstrapping iteration 861/1000
# The free energy difference from a BAR calculation is    -0.60
# Bootstrapping iteration 862/1000
# The free energy difference from a BAR calculation is    -0.43
# Bootstrapping iteration 863/1000
# The free energy difference from a BAR calculation is    -0.49
# Bootstrapping iteration 864/1000
# The free energy difference from a BAR calculation is    -0.50
# Bootstrapping iteration 865/1000
# The free energy difference from a BAR calculation is    -0.48
# Bootstrapping iteration 866/1000
# The free energy difference from a BAR calculation is    -0.43
# Bootstrapping iteration 867/1000
# The free energy difference from a BAR calculation is    -0.44
# Bootstrapping iteration 868/1000
# The free energy difference from a BAR calculation is    -0.40
# Bootstrapping iteration 869/1000
# The free energy difference from a BAR calculation is    -0.40
# Bootstrapping iteration 870/1000
# The free energy difference from a BAR calculation is    -0.47
# Bootstrapping iteration 871/1000
# The free energy difference from a BAR calculation is    -0.57
# Bootstrapping iteration 872/1000
# The free energy difference from a BAR calculation is    -0.48
# Bootstrapping iteration 873/1000
# The free energy difference from a BAR calculation is    -0.53
# Bootstrapping iteration 874/1000
# The free energy difference from a BAR calculation is    -0.49
# Bootstrapping iteration 875/1000
# The free energy difference from a BAR calculation is    -0.46
# Bootstrapping iteration 876/1000
# The free energy difference from a BAR calculation is    -0.45
# Bootstrapping iteration 877/1000
# The free energy difference from a BAR calculation is    -0.50
# Bootstrapping iteration 878/1000
# The free energy difference from a BAR calculation is    -0.49
# Bootstrapping iteration 879/1000
# The free energy difference from a BAR calculation is    -0.48
# Bootstrapping iteration 880/1000
# The free energy difference from a BAR calculation is    -0.49
# Bootstrapping iteration 881/1000
# The free energy difference from a BAR calculation is    -0.49
# Bootstrapping iteration 882/1000
# The free energy difference from a BAR calculation is    -0.42
# Bootstrapping iteration 883/1000
# The free energy difference from a BAR calculation is    -0.39
# Bootstrapping iteration 884/1000
# The free energy difference from a BAR calculation is    -0.46
# Bootstrapping iteration 885/1000
# The free energy difference from a BAR calculation is    -0.44
# Bootstrapping iteration 886/1000
# The free energy difference from a BAR calculation is    -0.41
# Bootstrapping iteration 887/1000
# The free energy difference from a BAR calculation is    -0.51
# Bootstrapping iteration 888/1000
# The free energy difference from a BAR calculation is    -0.47
# Bootstrapping iteration 889/1000
# The free energy difference from a BAR calculation is    -0.40
# Bootstrapping iteration 890/1000
# The free energy difference from a BAR calculation is    -0.44
# Bootstrapping iteration 891/1000
# The free energy difference from a BAR calculation is    -0.46
# Bootstrapping iteration 892/1000
# The free energy difference from a BAR calculation is    -0.52
# Bootstrapping iteration 893/1000
# The free energy difference from a BAR calculation is    -0.52
# Bootstrapping iteration 894/1000
# The free energy difference from a BAR calculation is    -0.41
# Bootstrapping iteration 895/1000
# The free energy difference from a BAR calculation is    -0.44
# Bootstrapping iteration 896/1000
# The free energy difference from a BAR calculation is    -0.48
# Bootstrapping iteration 897/1000
# The free energy difference from a BAR calculation is    -0.40
# Bootstrapping iteration 898/1000
# The free energy difference from a BAR calculation is    -0.49
# Bootstrapping iteration 899/1000
# The free energy difference from a BAR calculation is    -0.48
# Bootstrapping iteration 900/1000
# The free energy difference from a BAR calculation is    -0.58
# Bootstrapping iteration 901/1000
# The free energy difference from a BAR calculation is    -0.37
# Bootstrapping iteration 902/1000
# The free energy difference from a BAR calculation is    -0.40
# Bootstrapping iteration 903/1000
# The free energy difference from a BAR calculation is    -0.51
# Bootstrapping iteration 904/1000
# The free energy difference from a BAR calculation is    -0.44
# Bootstrapping iteration 905/1000
# The free energy difference from a BAR calculation is    -0.46
# Bootstrapping iteration 906/1000
# The free energy difference from a BAR calculation is    -0.49
# Bootstrapping iteration 907/1000
# The free energy difference from a BAR calculation is    -0.48
# Bootstrapping iteration 908/1000
# The free energy difference from a BAR calculation is    -0.52
# Bootstrapping iteration 909/1000
# The free energy difference from a BAR calculation is    -0.44
# Bootstrapping iteration 910/1000
# The free energy difference from a BAR calculation is    -0.54
# Bootstrapping iteration 911/1000
# The free energy difference from a BAR calculation is    -0.48
# Bootstrapping iteration 912/1000
# The free energy difference from a BAR calculation is    -0.50
# Bootstrapping iteration 913/1000
# The free energy difference from a BAR calculation is    -0.45
# Bootstrapping iteration 914/1000
# The free energy difference from a BAR calculation is    -0.47
# Bootstrapping iteration 915/1000
# The free energy difference from a BAR calculation is    -0.46
# Bootstrapping iteration 916/1000
# The free energy difference from a BAR calculation is    -0.49
# Bootstrapping iteration 917/1000
# The free energy difference from a BAR calculation is    -0.45
# Bootstrapping iteration 918/1000
# The free energy difference from a BAR calculation is    -0.42
# Bootstrapping iteration 919/1000
# The free energy difference from a BAR calculation is    -0.44
# Bootstrapping iteration 920/1000
# The free energy difference from a BAR calculation is    -0.50
# Bootstrapping iteration 921/1000
# The free energy difference from a BAR calculation is    -0.45
# Bootstrapping iteration 922/1000
# The free energy difference from a BAR calculation is    -0.41
# Bootstrapping iteration 923/1000
# The free energy difference from a BAR calculation is    -0.56
# Bootstrapping iteration 924/1000
# The free energy difference from a BAR calculation is    -0.41
# Bootstrapping iteration 925/1000
# The free energy difference from a BAR calculation is    -0.47
# Bootstrapping iteration 926/1000
# The free energy difference from a BAR calculation is    -0.47
# Bootstrapping iteration 927/1000
# The free energy difference from a BAR calculation is    -0.46
# Bootstrapping iteration 928/1000
# The free energy difference from a BAR calculation is    -0.40
# Bootstrapping iteration 929/1000
# The free energy difference from a BAR calculation is    -0.46
# Bootstrapping iteration 930/1000
# The free energy difference from a BAR calculation is    -0.42
# Bootstrapping iteration 931/1000
# The free energy difference from a BAR calculation is    -0.46
# Bootstrapping iteration 932/1000
# The free energy difference from a BAR calculation is    -0.40
# Bootstrapping iteration 933/1000
# The free energy difference from a BAR calculation is    -0.47
# Bootstrapping iteration 934/1000
# The free energy difference from a BAR calculation is    -0.45
# Bootstrapping iteration 935/1000
# The free energy difference from a BAR calculation is    -0.48
# Bootstrapping iteration 936/1000
# The free energy difference from a BAR calculation is    -0.51
# Bootstrapping iteration 937/1000
# The free energy difference from a BAR calculation is    -0.64
# Bootstrapping iteration 938/1000
# The free energy difference from a BAR calculation is    -0.40
# Bootstrapping iteration 939/1000
# The free energy difference from a BAR calculation is    -0.45
# Bootstrapping iteration 940/1000
# The free energy difference from a BAR calculation is    -0.49
# Bootstrapping iteration 941/1000
# The free energy difference from a BAR calculation is    -0.47
# Bootstrapping iteration 942/1000
# The free energy difference from a BAR calculation is    -0.42
# Bootstrapping iteration 943/1000
# The free energy difference from a BAR calculation is    -0.54
# Bootstrapping iteration 944/1000
# The free energy difference from a BAR calculation is    -0.35
# Bootstrapping iteration 945/1000
# The free energy difference from a BAR calculation is    -0.52
# Bootstrapping iteration 946/1000
# The free energy difference from a BAR calculation is    -0.47
# Bootstrapping iteration 947/1000
# The free energy difference from a BAR calculation is    -0.52
# Bootstrapping iteration 948/1000
# The free energy difference from a BAR calculation is    -0.45
# Bootstrapping iteration 949/1000
# The free energy difference from a BAR calculation is    -0.44
# Bootstrapping iteration 950/1000
# The free energy difference from a BAR calculation is    -0.35
# Bootstrapping iteration 951/1000
# The free energy difference from a BAR calculation is    -0.50
# Bootstrapping iteration 952/1000
# The free energy difference from a BAR calculation is    -0.45
# Bootstrapping iteration 953/1000
# The free energy difference from a BAR calculation is    -0.47
# Bootstrapping iteration 954/1000
# The free energy difference from a BAR calculation is    -0.39
# Bootstrapping iteration 955/1000
# The free energy difference from a BAR calculation is    -0.47
# Bootstrapping iteration 956/1000
# The free energy difference from a BAR calculation is    -0.42
# Bootstrapping iteration 957/1000
# The free energy difference from a BAR calculation is    -0.49
# Bootstrapping iteration 958/1000
# The free energy difference from a BAR calculation is    -0.46
# Bootstrapping iteration 959/1000
# The free energy difference from a BAR calculation is    -0.50
# Bootstrapping iteration 960/1000
# The free energy difference from a BAR calculation is    -0.45
# Bootstrapping iteration 961/1000
# The free energy difference from a BAR calculation is    -0.50
# Bootstrapping iteration 962/1000
# The free energy difference from a BAR calculation is    -0.47
# Bootstrapping iteration 963/1000
# The free energy difference from a BAR calculation is    -0.42
# Bootstrapping iteration 964/1000
# The free energy difference from a BAR calculation is    -0.50
# Bootstrapping iteration 965/1000
# The free energy difference from a BAR calculation is    -0.48
# Bootstrapping iteration 966/1000
# The free energy difference from a BAR calculation is    -0.48
# Bootstrapping iteration 967/1000
# The free energy difference from a BAR calculation is    -0.41
# Bootstrapping iteration 968/1000
# The free energy difference from a BAR calculation is    -0.42
# Bootstrapping iteration 969/1000
# The free energy difference from a BAR calculation is    -0.43
# Bootstrapping iteration 970/1000
# The free energy difference from a BAR calculation is    -0.54
# Bootstrapping iteration 971/1000
# The free energy difference from a BAR calculation is    -0.58
# Bootstrapping iteration 972/1000
# The free energy difference from a BAR calculation is    -0.52
# Bootstrapping iteration 973/1000
# The free energy difference from a BAR calculation is    -0.50
# Bootstrapping iteration 974/1000
# The free energy difference from a BAR calculation is    -0.51
# Bootstrapping iteration 975/1000
# The free energy difference from a BAR calculation is    -0.41
# Bootstrapping iteration 976/1000
# The free energy difference from a BAR calculation is    -0.43
# Bootstrapping iteration 977/1000
# The free energy difference from a BAR calculation is    -0.39
# Bootstrapping iteration 978/1000
# The free energy difference from a BAR calculation is    -0.46
# Bootstrapping iteration 979/1000
# The free energy difference from a BAR calculation is    -0.54
# Bootstrapping iteration 980/1000
# The free energy difference from a BAR calculation is    -0.47
# Bootstrapping iteration 981/1000
# The free energy difference from a BAR calculation is    -0.44
# Bootstrapping iteration 982/1000
# The free energy difference from a BAR calculation is    -0.52
# Bootstrapping iteration 983/1000
# The free energy difference from a BAR calculation is    -0.47
# Bootstrapping iteration 984/1000
# The free energy difference from a BAR calculation is    -0.44
# Bootstrapping iteration 985/1000
# The free energy difference from a BAR calculation is    -0.48
# Bootstrapping iteration 986/1000
# The free energy difference from a BAR calculation is    -0.48
# Bootstrapping iteration 987/1000
# The free energy difference from a BAR calculation is    -0.42
# Bootstrapping iteration 988/1000
# The free energy difference from a BAR calculation is    -0.37
# Bootstrapping iteration 989/1000
# The free energy difference from a BAR calculation is    -0.50
# Bootstrapping iteration 990/1000
# The free energy difference from a BAR calculation is    -0.42
# Bootstrapping iteration 991/1000
# The free energy difference from a BAR calculation is    -0.43
# Bootstrapping iteration 992/1000
# The free energy difference from a BAR calculation is    -0.40
# Bootstrapping iteration 993/1000
# The free energy difference from a BAR calculation is    -0.47
# Bootstrapping iteration 994/1000
# The free energy difference from a BAR calculation is    -0.42
# Bootstrapping iteration 995/1000
# The free energy difference from a BAR calculation is    -0.45
# Bootstrapping iteration 996/1000
# The free energy difference from a BAR calculation is    -0.45
# Bootstrapping iteration 997/1000
# The free energy difference from a BAR calculation is    -0.54
# Bootstrapping iteration 998/1000
# The free energy difference from a BAR calculation is    -0.57
# Bootstrapping iteration 999/1000
# The free energy difference from a BAR calculation is    -0.53
# Bootstrapping iteration 1000/1000
# The free energy difference from a BAR calculation is    -0.44
#
# The free energy difference from a BAR calculation is    -0.46 +-  0.05
#
# The free energy difference from a forward TP calculation is     0.45 +-  0.30
# The dissipated work in a forward TP is     3.18
# The free energy difference from a backward TP calculation is    -0.92 +-  0.09
# The dissipated work in a backward TP is    16.32
# The free energy difference from the weighted average of the backward TP and forward TP is    -0.81 +-  0.09

# %% [markdown]
# In the following, we will use another sampling method termed stratified sampling. In this method, we first introduce a series of intermediate states with a Hamiltonian $H_\lambda=\lambda H_1+(1-\lambda)H_0,\, \lambda \in (0,1)$. When $\lambda=0,\, H_\lambda=H_0$. And $H_\lambda=H_1$, when $\lambda=1$. The function for $H_\lambda$ is:

# %%
def ulmbd(lamb,x):
    return (1-lamb)*u0(x)+lamb*u1(x)

# %% [markdown]
# We can plot the potential energy surfaces

# %%
x=np.linspace(-5,6,100)
y0=ulmbd(0.0,x)
y1=ulmbd(0.1,x)
y2=ulmbd(0.2,x)
y5=ulmbd(0.5,x)
y8=ulmbd(0.8,x)
y9=ulmbd(0.9,x)
yN=ulmbd(1.0,x)
plt.ylim(-.5, 3)
plt.plot(x,y0,'r')
plt.plot(x,yN,'b')
plt.plot(x,y1)
plt.plot(x,y2)
plt.plot(x,y5)
plt.plot(x,y8)
plt.plot(x,y9)
plt.show()

# %% [markdown]
# The free energy difference between $H_0$ and $H_1$ can be written as the sum of the free energy difference between each pair of neighboring states, i.e.
# $$\Delta A_{0\rightarrow 1}=\sum\limits_{i=0}^{N-1}\Delta A_{\lambda_i\rightarrow \lambda_{i+1}}$$
# We keep the total number of samples fixed and evenly distribute the samples to each simulation under $H_\lambda$.

# %%
def MCpropagator2(x0,dx,N,dN,ulmbd,lamb):
    count = 0
    x = np.empty(N)
    xcurrent = x0
    while count < N:
        innercount = 0
        while innercount < dN:
            rnd = np.random.uniform(0.,1.)
            if rnd<0.5:
                xtrial = xcurrent - dx
            else:
                xtrial = xcurrent + dx

            deltau = ulmbd(lamb,xtrial) - ulmbd(lamb,xcurrent)
            if deltau < 0:
                xcurrent = xtrial
            else:
                acceptanceratio = np.exp(-deltau)
                if acceptanceratio > np.random.uniform(0.0,1.0):
                    xcurrent = xtrial
                else:
                    xcurrent = xcurrent
            innercount = innercount + 1
        x[count] = xcurrent
        count = count + 1
    return x, count

def TP2(x,ulmbd,lmbd1,lmbd2):
    edu=np.zeros(x.size)
    edu = np.exp(-(ulmbd(lmbd2,x)-ulmbd(lmbd1,x)))
    S = np.mean(edu)
    varS = np.var(edu)/x.size
    deltaA = -np.log(S)
    varA = varS/S**2
    return deltaA, varA

# %%
dx = 0.01
N=10000
dlambda = 0.1
lambs = np.arange(0.0,1.,dlambda)
lambs = np.append(lambs,[1.0])
Ns = N//(len(lambs)-1)
deltaA = np.zeros(len(lambs)-1)
varA = np.zeros(len(lambs)-1)
i = 0
for i in range(len(lambs)-1):
    x0 = -1.5 + 3.0*i*dlambda
    x = np.empty(Ns)
    x, count = MCpropagator2(x0,dx,Ns,dN,ulmbd,lambs[i])
#    print('Number of samples generated:%8d for lambda= %5.2f' %(count,lambs[i]))
    prob, bins, patches = plt.hist(x, bins=50, density=True)
    mean = np.mean(x)
    variance = np.var(x)
    sigma = np.sqrt(variance)
    npdf = scipy.stats.norm.pdf(bins,mean,sigma)
    plt.plot(bins, npdf, '--')
    deltaA[i], varA[i] = TP2(x,ulmbd,lambs[i],lambs[i+1])
    print('The free energy difference from lambda %4.2f to lambda %4.2f is %8.2f +- %5.2f' % (lambs[i],lambs[i+1],deltaA[i], np.sqrt(varA[i])))

print('')
print('The total free energy difference is %8.2f +- %5.2f' %(np.sum(deltaA),np.sqrt(np.sum(varA))))
plt.show()
# Out:
# The free energy difference from lambda 0.00 to lambda 0.10 is     0.35 +-  0.01
# The free energy difference from lambda 0.10 to lambda 0.20 is     0.29 +-  0.01
# The free energy difference from lambda 0.20 to lambda 0.30 is     0.33 +-  0.00
# The free energy difference from lambda 0.30 to lambda 0.40 is     0.23 +-  0.01
# The free energy difference from lambda 0.40 to lambda 0.50 is     0.21 +-  0.01
# The free energy difference from lambda 0.50 to lambda 0.60 is     0.10 +-  0.01
# The free energy difference from lambda 0.60 to lambda 0.70 is    -0.01 +-  0.02
# The free energy difference from lambda 0.70 to lambda 0.80 is    -0.09 +-  0.01
# The free energy difference from lambda 0.80 to lambda 0.90 is    -0.78 +-  0.04
# The free energy difference from lambda 0.90 to lambda 1.00 is    -1.46 +-  0.07
#
# The total free energy difference is    -0.84 +-  0.09
